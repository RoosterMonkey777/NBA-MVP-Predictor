# %% [markdown]
# # NBA MVP Prediction - Data cleaning
#
# This part of the project will seek to clean, transform and combine the csv's created in the web scraping script. It is important to clean the data for any project.

# %%
import pandas as pd

# %%
mvps = pd.read_csv("mvps.csv")

# %%
mvps
# Out:
#      Unnamed: 0 Rank           Player  Age   Tm  First  Pts Won  Pts Max  \
# 0             0    1   Michael Jordan   27  CHI   77.0    891.0      960
# 1             1    2    Magic Johnson   31  LAL   10.0    497.0      960
# 2             2    3   David Robinson   25  SAS    6.0    476.0      960
# 3             3    4  Charles Barkley   27  PHI    2.0    222.0      960
# 4             4    5      Karl Malone   27  UTA    0.0    142.0      960
# ..          ...  ...              ...  ...  ...    ...      ...      ...
# 454           7    8   Damian Lillard   29  POR    0.0     23.0     1010
# 455           8    9     Nikola Jokić   24  DEN    0.0     18.0     1010
# 456           9   10    Pascal Siakam   25  TOR    0.0     17.0     1010
# 457          10   11     Jimmy Butler   30  MIA    0.0      9.0     1010
# 458          11   12     Jayson Tatum   21  BOS    0.0      1.0     1010
#
#      Share   G  ...   TRB   AST  STL  BLK    FG%    3P%    FT%    WS  WS/48  \
# ...

# %% [markdown]
# ### Cleaning mvps dataset
# Will do some data cleaning on this dataset. We only need a couple of columns from this dataset as alot of the data is also in the player stats csv

# %%
col_names = mvps.columns
print(col_names)
# Out:
# Index(['Unnamed: 0', 'Rank', 'Player', 'Age', 'Tm', 'First', 'Pts Won',
#        'Pts Max', 'Share', 'G', 'MP', 'PTS', 'TRB', 'AST', 'STL', 'BLK', 'FG%',
#        '3P%', 'FT%', 'WS', 'WS/48', 'Year'],
#       dtype='object')

# %%
# filter only the columns we want:
mvps = mvps[["Player", "Year", "Pts Won", "Pts Max", "Share"]]

# %%
mvps.head()
# Out:
#             Player  Year  Pts Won  Pts Max  Share
# 0   Michael Jordan  1991    891.0      960  0.928
# 1    Magic Johnson  1991    497.0      960  0.518
# 2   David Robinson  1991    476.0      960  0.496
# 3  Charles Barkley  1991    222.0      960  0.231
# 4      Karl Malone  1991    142.0      960  0.148

# %% [markdown]
# ### Cleaning player stats dataset

# %%
players = pd.read_csv("players.csv")

# %%
players
# Out:
#        Unnamed: 0   Rk              Player Pos Age   Tm   G  GS    MP   FG  \
# 0               0    1      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3
# 1               1    2  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2
# 2               2    3          Mark Acres   C  28  ORL  68   0  19.3  1.6
# 3               3    4       Michael Adams  PG  28  DEN  66  66  35.5  8.5
# 4               4    5        Mark Aguirre  SF  31  DET  78  13  25.7  5.4
# ...           ...  ...                 ...  ..  ..  ...  ..  ..   ...  ...
# 18039         725  536        Delon Wright  PG  28  SAC  27   8  25.8  3.9
# 18040         726  537      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4
# 18041         727  538          Trae Young  PG  22  ATL  63  63  33.7  7.7
# 18042         728  539         Cody Zeller   C  28  CHO  48  21  20.9  3.8
# 18043         729  540         Ivica Zubac   C  23  LAC  72  33  22.3  3.6
#
#        ...  ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %%
del players["Rk"]

# %%
players
# Out:
#        Unnamed: 0              Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# 0               0      Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7
# 1               1  Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1
# 2               2          Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1
# 3               3       Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5
# 4               4        Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7
# ...           ...                 ...  ..  ..  ...  ..  ..   ...  ...   ...
# 18039         725        Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3
# 18040         726      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7
# 18041         727          Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7
# 18042         728         Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8
# 18043         729         Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5
#
# ...

# %%
del players["Unnamed: 0"]

# %%
players
# Out:
#                    Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  \
# 0          Alaa Abdelnaby  PF  22  POR  43   0   6.7  1.3   2.7  .474  ...
# 1      Mahmoud Abdul-Rauf  PG  21  DEN  67  19  22.5  6.2  15.1  .413  ...
# 2              Mark Acres   C  28  ORL  68   0  19.3  1.6   3.1  .509  ...
# 3           Michael Adams  PG  28  DEN  66  66  35.5  8.5  21.5  .394  ...
# 4            Mark Aguirre  SF  31  DET  78  13  25.7  5.4  11.7  .462  ...
# ...                   ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...
# 18039        Delon Wright  PG  28  SAC  27   8  25.8  3.9   8.3  .462  ...
# 18040      Thaddeus Young  PF  32  CHI  68  23  24.3  5.4   9.7  .559  ...
# 18041          Trae Young  PG  22  ATL  63  63  33.7  7.7  17.7  .438  ...
# 18042         Cody Zeller   C  28  CHO  48  21  20.9  3.8   6.8  .559  ...
# 18043         Ivica Zubac   C  23  LAC  72  33  22.3  3.6   5.5  .652  ...
#
#        ORB  DRB  TRB   AST  STL  BLK  TOV   PF   PTS  Year
# ...

# %% [markdown]
# We want to merge the data from **mvps dataset** to the same players and year in **players dataset**, however some of the dataformat differs between the two datasets (some names in players has a * which is not their on the mvps). To avoid error and have them match all characters, we need to remove the *

# %%
# to remove the * we will use the .str.replace() method

#pandas uses * as regex (which has a meaning), so we need to make it false for literal *
players["Player"] = players["Player"].str.replace("*", "", regex=False)

# %%
players.head(50)
# Out:
#                 Player    Pos  Age   Tm   G  GS    MP   FG   FGA    FG%  ...  \
# 0       Alaa Abdelnaby     PF   22  POR  43   0   6.7  1.3   2.7   .474  ...
# 1   Mahmoud Abdul-Rauf     PG   21  DEN  67  19  22.5  6.2  15.1   .413  ...
# 2           Mark Acres      C   28  ORL  68   0  19.3  1.6   3.1   .509  ...
# 3        Michael Adams     PG   28  DEN  66  66  35.5  8.5  21.5   .394  ...
# 4         Mark Aguirre     SF   31  DET  78  13  25.7  5.4  11.7   .462  ...
# 5          Danny Ainge     SG   31  POR  80   0  21.4  4.2   8.9   .472  ...
# 6          Mark Alarie     PF   27  WSB  42   1  14.0  2.4   5.4   .440  ...
# 7         Steve Alford     PG   26  DAL  34   0   6.9  1.7   3.4   .504  ...
# 8        Greg Anderson     PF   26  TOT  68   2  13.6  1.7   4.0   .430  ...
# 9        Greg Anderson     PF   26  MIL  26   0   9.5  1.0   2.8   .370  ...
# 10       Greg Anderson     PF   26  NJN   1   0  18.0  4.0   4.0  1.000  ...
# ...

# %% [markdown]
# Notice how all the * have been removed

# %% [markdown]
# **Also notice in the dataset that their are names being repeated many times (because they played for various teams that season), we just want the total stats so we have to take care of that**

# %%
players.groupby(["Player", "Year"])

# %%
players.groupby(["Player", "Year"]).get_group(("Greg Anderson", 1991))
# Out:
#            Player Pos Age   Tm   G GS    MP   FG  FGA    FG%  ...  ORB  DRB  \
# 8   Greg Anderson  PF  26  TOT  68  2  13.6  1.7  4.0   .430  ...  1.4  3.3
# 9   Greg Anderson  PF  26  MIL  26  0   9.5  1.0  2.8   .370  ...  1.0  1.9
# 10  Greg Anderson  PF  26  NJN   1  0  18.0  4.0  4.0  1.000  ...  4.0  2.0
# 11  Greg Anderson  PF  26  DEN  41  2  16.1  2.1  4.7   .440  ...  1.6  4.1
#
#     TRB  AST  STL  BLK  TOV   PF  PTS  Year
# 8   4.7  0.2  0.5  0.7  1.2  2.1  4.3  1991
# 9   2.9  0.1  0.3  0.3  0.8  1.1  2.7  1991
# 10  6.0  1.0  2.0  0.0  1.0  4.0  8.0  1991
# 11  5.8  0.3  0.6  0.9  1.5  2.6  5.2  1991
#
# [4 rows x 30 columns]

# %% [markdown]
# We can iterate through each group and make sure each group only has one row.
#
# We will do this by writing a function.

# %%
def single_row(df):
    if df.shape[0] == 1: # if there is only one row just leave it
        return df
    else:
        row = df[df["Tm"] == "TOT"] # TOT doesnt match the mvp data, so we need to replace it with the last team they played for
        row["Tm"] = df.iloc[-1,:]["Tm"] # the team in the last row
        return row

# %%
# now we can use the .apply() method to apply the function to each group
players = players.groupby(["Player", "Year"]).apply(single_row)

# %%
players.head(20)
# Out:
#                                  Player Pos Age   Tm   G  GS    MP   FG   FGA  \
# Player        Year
# A.C. Green    1991 164       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6
#               1992 633       A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8
#               1993 1092      A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6
#               1994 1579      A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3
#               1995 2067      A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5
#               1996 2563      A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4
#               1997 3138      A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8
#               1998 3725      A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5
#               1999 4283      A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1
#               2000 4811      A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7
#               2001 5330      A.C. Green  PF  37  MIA  82   1  17.2  1.8   4.0
# ...

# %% [markdown]
# We can drop two of the index levels that were created as a result of grouping and combining the dataframes. We can do this by dropping the first two levels

# %%
players.index = players.index.droplevel()

# %%
players.index = players.index.droplevel()

# %%
players[players["Player"] == "Greg Anderson"]
# Out:
#              Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  ORB  \
# 8     Greg Anderson  PF  26  DEN  68   2  13.6  1.7   4.0  .430  ...  1.4
# 467   Greg Anderson  PF  27  DEN  82  82  34.1  4.7  10.4  .456  ...  4.1
# 1412  Greg Anderson  PF  29  DET  77  47  21.1  2.6   4.8  .543  ...  2.4
# 1911  Greg Anderson  PF  30  ATL  51   0  12.2  1.1   2.0  .548  ...  1.2
# 2381  Greg Anderson  PF  31  SAS  46   7   7.5  0.5   1.0  .511  ...  0.6
# 2948  Greg Anderson   C  32  SAS  82  48  20.2  1.6   3.2  .496  ...  1.9
# 3541  Greg Anderson   C  33  ATL  50   0   8.0  0.7   1.6  .444  ...  0.8
#
#       DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Year
# 8     3.3   4.7  0.2  0.5  0.7  1.2  2.1   4.3  1991
# 467   7.4  11.5  1.0  1.1  0.8  2.5  3.2  11.5  1992
# 1412  5.0   7.4  0.7  0.7  0.9  1.2  3.0   6.4  1994
# 1911  2.5   3.7  0.3  0.5  0.6  0.6  2.0   2.9  1995
# 2381  1.5   2.2  0.2  0.2  0.5  0.5  1.4   1.2  1996
# 2948  3.5   5.5  0.4  0.8  0.8  0.9  2.7   3.9  1997
# ...

# %% [markdown]
# Can now see duplicate players only show up once with the last team they played for that season

# %% [markdown]
# Now we want to merge our two dataframes : mvps and players

# %%
combined_df = players.merge(mvps, how="outer", on=["Player", "Year"])

# %%
combined_df.head()
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7  0.3
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1  0.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1  0.5
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7  0.4
#
#    TOV   PF   PTS  Year Pts Won Pts Max Share
# 0  1.2  1.4   9.1  1991     NaN     NaN   NaN
# 1  1.4  1.7  13.6  1992     NaN     NaN   NaN
# 2  1.4  1.8  12.8  1993     NaN     NaN   NaN
# 3  1.2  1.7  14.7  1994     NaN     NaN   NaN
# 4  1.4  1.8  11.2  1995     NaN     NaN   NaN
#
# [5 rows x 33 columns]

# %% [markdown]
# Notice how bow all the columns from the mvps dataset is combined with the players dataset, and because there are no values for those players, they are replaced with NaN

# %%
combined_df[combined_df["Pts Won"]> 0]
# Out:
#               Player    Pos Age   Tm   G  GS    MP    FG   FGA   FG%  ...  \
# 187     Al Jefferson      C  29  CHA  73  73  35.0   9.6  18.8  .509  ...
# 329    Allen Iverson     PG  21  PHI  76  74  40.1   8.2  19.8  .416  ...
# 331    Allen Iverson     SG  23  PHI  48  48  41.5   9.1  22.0  .412  ...
# 332    Allen Iverson     SG  24  PHI  70  70  40.8  10.4  24.8  .421  ...
# 333    Allen Iverson     SG  25  PHI  71  71  42.0  10.7  25.5  .420  ...
# ...              ...    ...  ..  ...  ..  ..   ...   ...   ...   ...  ...
# 13587   Vince Carter     SF  23  TOR  82  82  38.1   9.6  20.7  .465  ...
# 13588   Vince Carter     SF  24  TOR  75  75  39.7  10.2  22.1  .460  ...
# 13592   Vince Carter  SF-SG  28  NJN  77  76  36.7   9.0  20.0  .452  ...
# 13952       Yao Ming      C  23  HOU  82  82  32.8   6.5  12.5  .522  ...
# 13957       Yao Ming      C  28  HOU  77  77  33.6   7.4  13.4  .548  ...
#
#        AST  STL  BLK  TOV   PF   PTS  Year Pts Won Pts Max  Share
# ...

# %% [markdown]
# Need to fix tha Nan by replacing with 0's

# %%
combined_df[["Pts Won", "Pts Max", "Share"]] = combined_df[["Pts Won", "Pts Max", "Share"]].fillna(0)

# %%
combined_df.head()
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  AST  STL  BLK  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.9  0.7  0.3
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.4  1.1  0.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.4  1.1  0.5
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  1.7  0.9  0.5
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  1.5  0.7  0.4
#
#    TOV   PF   PTS  Year Pts Won Pts Max Share
# 0  1.2  1.4   9.1  1991     0.0     0.0   0.0
# 1  1.4  1.7  13.6  1992     0.0     0.0   0.0
# 2  1.4  1.8  12.8  1993     0.0     0.0   0.0
# 3  1.2  1.7  14.7  1994     0.0     0.0   0.0
# 4  1.4  1.8  11.2  1995     0.0     0.0   0.0
#
# [5 rows x 33 columns]

# %% [markdown]
# ### Cleaning the Team Data

# %%
teams = pd.read_csv("teams.csv")

# %%
teams
# Out:
#      Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G    SRS  Year  \
# 0             0  56  26  .683     —  111.5  105.7   5.22  1991
# 1             1  44  38  .537  12.0  105.4  105.6  -0.39  1991
# 2             2  39  43  .476  17.0  103.1  103.3  -0.43  1991
# 3             3  30  52  .366  26.0  101.4  106.4  -4.84  1991
# 4             4  26  56  .317  30.0  102.9  107.5  -4.53  1991
# ..          ...  ..  ..   ...   ...    ...    ...    ...   ...
# 993          13  44  28  .611     —  117.8  114.8   3.13  2020
# 994          14  43  32  .573   2.5  117.0  112.1   4.87  2020
# 995          15  34  39  .466  10.5  112.6  113.7  -0.91  2020
# 996          16  32  39  .451  11.5  114.1  115.2  -0.65  2020
# 997          17  30  42  .417  14.0  115.8  117.1  -0.55  2020
#
#                      Team
# 0         Boston Celtics*
# 1     Philadelphia 76ers*
# 2        New York Knicks*
# 3      Washington Bullets
# 4         New Jersey Nets
# ..                    ...
# ...

# %%
teams.head(20)
# Out:
#     Unnamed: 0                 W                 L              W/L%  \
# 0            0                56                26              .683
# 1            1                44                38              .537
# 2            2                39                43              .476
# 3            3                30                52              .366
# 4            4                26                56              .317
# 5            5                24                58              .293
# 6            6  Central Division  Central Division  Central Division
# 7            7                61                21              .744
# 8            8                50                32              .610
# 9            9                48                34              .585
# 10          10                43                39              .524
# 11          11                41                41              .500
# 12          12                33                49              .402
# ...

# %% [markdown]
# Notice how in this dataset there are string about the division, we need to remove these.

# %%
#  filtering the DataFrame teams to exclude rows where the "W" column contains the string "Division"
teams = teams[~teams["W"].str.contains("Division")]

# %%
teams.head(20)
# Out:
#     Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G     SRS  Year  \
# 0            0  56  26  .683     —  111.5  105.7    5.22  1991
# 1            1  44  38  .537  12.0  105.4  105.6   -0.39  1991
# 2            2  39  43  .476  17.0  103.1  103.3   -0.43  1991
# 3            3  30  52  .366  26.0  101.4  106.4   -4.84  1991
# 4            4  26  56  .317  30.0  102.9  107.5   -4.53  1991
# 5            5  24  58  .293  32.0  101.8  107.8   -5.91  1991
# 7            7  61  21  .744     —  110.0  101.0    8.57  1991
# 8            8  50  32  .610  11.0  100.1   96.8    3.08  1991
# 9            9  48  34  .585  13.0  106.4  104.0    2.33  1991
# 10          10  43  39  .524  18.0  109.8  109.0    0.72  1991
# 11          11  41  41  .500  20.0  111.7  112.1   -0.37  1991
# 12          12  33  49  .402  28.0  101.7  104.2   -2.33  1991
# 13          13  26  56  .317  35.0  102.8  108.0   -4.95  1991
# 15           1  55  27  .671     —  107.1  102.6    4.30  1991
# ...

# %% [markdown]
# Remove the team names with * in them like before

# %%
teams["Team"] = teams["Team"].str.replace("*", "", regex=False)
# Out:
# C:\Users\Zahaak\AppData\Local\Temp\ipykernel_15756\3338997264.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   teams["Team"] = teams["Team"].str.replace("*", "", regex=False)

# %%
teams.head(20)
# Out:
#     Unnamed: 0   W   L  W/L%    GB   PS/G   PA/G     SRS  Year  \
# 0            0  56  26  .683     —  111.5  105.7    5.22  1991
# 1            1  44  38  .537  12.0  105.4  105.6   -0.39  1991
# 2            2  39  43  .476  17.0  103.1  103.3   -0.43  1991
# 3            3  30  52  .366  26.0  101.4  106.4   -4.84  1991
# 4            4  26  56  .317  30.0  102.9  107.5   -4.53  1991
# 5            5  24  58  .293  32.0  101.8  107.8   -5.91  1991
# 7            7  61  21  .744     —  110.0  101.0    8.57  1991
# 8            8  50  32  .610  11.0  100.1   96.8    3.08  1991
# 9            9  48  34  .585  13.0  106.4  104.0    2.33  1991
# 10          10  43  39  .524  18.0  109.8  109.0    0.72  1991
# 11          11  41  41  .500  20.0  111.7  112.1   -0.37  1991
# 12          12  33  49  .402  28.0  101.7  104.2   -2.33  1991
# 13          13  26  56  .317  35.0  102.8  108.0   -4.95  1991
# 15           1  55  27  .671     —  107.1  102.6    4.30  1991
# ...

# %%
teams["Team"].unique() # look at the unique names in the Teams
# Out:
# array(['Boston Celtics', 'Philadelphia 76ers', 'New York Knicks',
#        'Washington Bullets', 'New Jersey Nets', 'Miami Heat',
#        'Chicago Bulls', 'Detroit Pistons', 'Milwaukee Bucks',
#        'Atlanta Hawks', 'Indiana Pacers', 'Cleveland Cavaliers',
#        'Charlotte Hornets', 'San Antonio Spurs', 'Utah Jazz',
#        'Houston Rockets', 'Orlando Magic', 'Minnesota Timberwolves',
#        'Dallas Mavericks', 'Denver Nuggets', 'Portland Trail Blazers',
#        'Los Angeles Lakers', 'Phoenix Suns', 'Golden State Warriors',
#        'Seattle SuperSonics', 'Los Angeles Clippers', 'Sacramento Kings',
#        'Toronto Raptors', 'Vancouver Grizzlies', 'Washington Wizards',
#        'Memphis Grizzlies', 'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans'], dtype=object)

# %%
combined_df["Tm"].unique()
# Out:
# array(['LAL', 'PHO', 'DAL', 'MIA', 'CLE', 'WSB', 'CHI', 'GSW', 'IND',
#        'WAS', 'MIN', 'BOS', 'HOU', 'DEN', 'ORL', 'NOH', 'TOR', 'SAC',
#        'CHO', 'POR', 'DET', 'PHI', 'UTA', 'MIL', 'VAN', 'SEA', 'NJN',
#        'NOK', 'LAC', 'OKC', 'ATL', 'CHA', 'MEM', 'NYK', 'NOP', 'BRK',
#        'SAS', 'CHH'], dtype=object)

# %%
unique_teams_sorted = sorted(combined_df["Tm"].unique())
unique_teams_sorted = sorted(teams["Team"].unique())
unique_teams_sorted
# Out:
# ['Atlanta Hawks',
#  'Boston Celtics',
#  'Brooklyn Nets',
#  'Charlotte Bobcats',
#  'Charlotte Hornets',
#  'Chicago Bulls',
#  'Cleveland Cavaliers',
#  'Dallas Mavericks',
#  'Denver Nuggets',
#  'Detroit Pistons',
#  'Golden State Warriors',
#  'Houston Rockets',
#  'Indiana Pacers',
#  'Los Angeles Clippers',
#  'Los Angeles Lakers',
#  'Memphis Grizzlies',
#  'Miami Heat',
#  'Milwaukee Bucks',
#  'Minnesota Timberwolves',
#  'New Jersey Nets',
#  'New Orleans Hornets',
#  'New Orleans Pelicans',
#  'New Orleans/Oklahoma City Hornets',
#  'New York Knicks',
#  'Oklahoma City Thunder',
#  'Orlando Magic',
#  'Philadelphia 76ers',
#  'Phoenix Suns',
#  'Portland Trail Blazers',
#  'Sacramento Kings',
#  'San Antonio Spurs',
#  'Seattle SuperSonics',
#  'Toronto Raptors',
#  'Utah Jazz',
#  'Vancouver Grizzlies',
#  'Washington Bullets',
#  'Washington Wizards']

# %% [markdown]
# Notice how in the combined dataframe, we have the short version of the team names

# %%
nicknames = {}

with open("nicknames.csv", encoding="utf-8") as f:
    lines = f.readlines()
    for line in lines[1:]: # skip first row 
        abbrev, name = line.replace("\n", "").split(",")
        nicknames[abbrev] = name

# %%
nicknames
# Out:
# {'ATL': 'Atlanta Hawks',
#  'BOS': 'Boston Celtics',
#  'BKN': 'Brooklyn Nets',
#  'BRK': 'Brooklyn Nets',
#  'CHA': 'Charlotte Bobcats',
#  'CHH': 'Charlotte Hornets',
#  'CHI': 'Chicago Bulls',
#  'CHO': 'Charlotte Hornets',
#  'CLE': 'Cleveland Cavaliers',
#  'DAL': 'Dallas Mavericks',
#  'DEN': 'Denver Nuggets',
#  'DET': 'Detroit Pistons',
#  'GSW': 'Golden State Warriors',
#  'HOU': 'Houston Rockets',
#  'IND': 'Indiana Pacers',
#  'LAC': 'Los Angeles Clippers',
#  'LAL': 'Los Angeles Lakers',
#  'MEM': 'Memphis Grizzlies',
#  'MIA': 'Miami Heat',
#  'MIL': 'Milwaukee Bucks',
#  'MIN': 'Minnesota Timberwolves',
#  'NJN': 'New Jersey Nets',
#  'NOH': 'New Orleans Hornets',
#  'NOP': 'New Orleans Pelicans',
#  'NOK': 'New Orleans/Oklahoma City Hornets',
#  'NYK': 'New York Knicks',
#  'OKC': 'Oklahoma City Thunder',
#  'ORL': 'Orlando Magic',
#  'PHI': 'Philadelphia 76ers',
#  'PHO': 'Phoenix Suns',
#  'PHX': 'Phoenix Suns',
#  'POR': 'Portland Trail Blazers',
# ...

# %% [markdown]
# can use pandas map method to create in the combined dataframe a full team name column

# %%
# applies a mapping function to each value in the "Tm" column. 
# The nicknames variable refers to a mapping function or a dictionary-like object containing mappings.
combined_df["Team"] = combined_df["Tm"].map(nicknames)

# %%
combined_df.head(10)
# Out:
#        Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  STL  BLK  TOV  \
# 0  A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.7  0.3  1.2
# 1  A.C. Green  PF  28  LAL  82  53  35.4  4.7   9.8  .476  ...  1.1  0.4  1.4
# 2  A.C. Green  PF  29  LAL  82  55  34.4  4.6   8.6  .537  ...  1.1  0.5  1.4
# 3  A.C. Green  PF  30  PHO  82  55  34.5  5.7  11.3  .502  ...  0.9  0.5  1.2
# 4  A.C. Green  SF  31  PHO  82  52  32.8  3.8   7.5  .504  ...  0.7  0.4  1.4
# 5  A.C. Green  SF  32  PHO  82  36  25.8  2.6   5.4  .484  ...  0.5  0.3  1.0
# 6  A.C. Green  PF  33  DAL  83  73  30.0  2.8   5.8  .483  ...  0.8  0.2  0.9
# 7  A.C. Green  PF  34  DAL  82  68  32.3  3.0   6.5  .453  ...  1.0  0.3  0.8
# 8  A.C. Green  PF  35  DAL  50  35  18.5  2.2   5.1  .422  ...  0.6  0.2  0.4
# 9  A.C. Green  PF  36  LAL  82  82  23.5  2.1   4.7  .447  ...  0.6  0.2  0.6
#
#     PF   PTS  Year Pts Won Pts Max Share                Team
# ...

# %% [markdown]
# Now we have everthing to make our final data set with the player stats and the teams names.

# %%
stats = combined_df.merge(teams, how="outer", on=["Team", "Year"])

# %%
stats.head(10)
# Out:
#             Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ...  Share  \
# 0       A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...  0.000
# 1      Byron Scott  SG  29  LAL  82  82  32.1  6.1  12.8  .477  ...  0.000
# 2   Elden Campbell  PF  22  LAL  52   0   7.3  1.1   2.4  .455  ...  0.000
# 3    Irving Thomas  PF  25  LAL  26   0   4.2  0.7   1.9  .340  ...  0.000
# 4     James Worthy  SF  29  LAL  78  74  38.6  9.2  18.7  .492  ...  0.000
# 5       Larry Drew  PG  32  LAL  48   2  10.3  1.1   2.6  .432  ...  0.000
# 6    Magic Johnson  PG  31  LAL  79  79  37.1  5.9  12.4  .477  ...  0.518
# 7  Mychal Thompson   C  36  LAL  72   4  15.0  1.6   3.2  .496  ...  0.000
# 8      Sam Perkins  PF  29  LAL  73  66  34.3  5.0  10.2  .495  ...  0.000
# 9     Terry Teagle  SG  30  LAL  82   0  18.3  4.1   9.2  .443  ...  0.000
#
#                  Team Unnamed: 0   W   L  W/L%   GB   PS/G  PA/G   SRS
# 0  Los Angeles Lakers       10.0  58  24  .707  5.0  106.3  99.6  6.73
# ...

# %%
stats
# Out:
#                Player Pos Age   Tm   G  GS    MP   FG   FGA   FG%  ... Share  \
# 0          A.C. Green  PF  27  LAL  82  21  26.4  3.1   6.6  .476  ...   0.0
# 1         Byron Scott  SG  29  LAL  82  82  32.1  6.1  12.8  .477  ...   0.0
# 2      Elden Campbell  PF  22  LAL  52   0   7.3  1.1   2.4  .455  ...   0.0
# 3       Irving Thomas  PF  25  LAL  26   0   4.2  0.7   1.9  .340  ...   0.0
# 4        James Worthy  SF  29  LAL  78  74  38.6  9.2  18.7  .492  ...   0.0
# ...               ...  ..  ..  ...  ..  ..   ...  ...   ...   ...  ...   ...
# 14087   Spencer Hawes  PF  28  MIL  54   1  14.8  2.5   5.1  .484  ...   0.0
# 14088     Steve Novak  PF  33  MIL   8   0   2.8  0.3   0.9  .286  ...   0.0
# 14089  Terrence Jones  PF  25  MIL  54  12  23.5  4.3   9.1  .470  ...   0.0
# 14090      Thon Maker   C  19  MIL  57  34   9.9  1.5   3.2  .459  ...   0.0
# 14091      Tony Snell  SG  25  MIL  80  80  29.2  3.1   6.8  .455  ...   0.0
#
# ...

# %%
combined_df.shape[1] + teams.shape[1] # (minus the teams and year so 42)
# Out:
# 44

# %%
del stats["Unnamed: 0"]

# %% [markdown]
# **Always want to check the datatypes of the columns**

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age         object
# Tm          object
# G           object
# GS          object
# MP          object
# FG          object
# FGA         object
# FG%         object
# 3P          object
# 3PA         object
# 3P%         object
# 2P          object
# 2PA         object
# 2P%         object
# eFG%        object
# FT          object
# FTA         object
# FT%         object
# ORB         object
# DRB         object
# TRB         object
# AST         object
# STL         object
# BLK         object
# TOV         object
# PF          object
# PTS         object
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W           object
# L           object
# W/L%        object
# GB          object
# PS/G        object
# PA/G        object
# SRS         object
# dtype: object

# %% [markdown]
# Currently pandas has them stored as objects or strings but we want to change them to a numerical value

# %%
# Will go through every column in stats and change the datatype to a numeric, and if it encounters error (already numeric) it ignores
stats = stats.apply(pd.to_numeric, errors="ignore")

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W          float64
# L          float64
# W/L%       float64
# GB          object
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %% [markdown]
# On closer inspection the GB is interesting because it should be a numerica but is still a string, take a close look:

# %%
stats["GB"].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '—', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '25.0', '8.0',
#        '19.0', '1.0', '13.0', '17.0', '3.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', nan, '16.0', '41.0', '12.0', '50.0', '10.0',
#        '30.0', '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0',
#        '39.0', '18.5', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '31.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5',
#        '11.5', '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5',
#        '4.5'], dtype=object)

# %% [markdown]
# Notice the '-' signifying 0 games back, lets replace this

# %%
stats["GB"] = stats["GB"].str.replace("—", "0")

# %%
stats["GB"] = stats["GB"].str.replace("nan", "0")

# %%
stats["GB"].unique()
# Out:
# array(['5.0', '14.0', '23.0', '7.0', '0', '40.0', '42.0', '18.0', '6.0',
#        '24.0', '26.0', '37.0', '29.0', '21.0', '28.0', '25.0', '8.0',
#        '19.0', '1.0', '13.0', '17.0', '3.0', '15.0', '9.0', '2.0', '35.0',
#        '20.0', '11.0', nan, '16.0', '41.0', '12.0', '50.0', '10.0',
#        '30.0', '34.0', '4.0', '1.5', '22.0', '51.0', '36.0', '43.0',
#        '39.0', '18.5', '48.0', '46.0', '10.5', '32.0', '38.0', '27.0',
#        '33.0', '31.0', '21.5', '45.0', '22.5', '25.5', '3.5', '20.5',
#        '11.5', '44.0', '52.0', '56.0', '2.5', '12.5', '47.0', '32.5',
#        '4.5'], dtype=object)

# %%
stats["GB"] = pd.to_numeric(stats["GB"])

# %% [markdown]
# Can see now the GB is a numeric value

# %%
stats.dtypes
# Out:
# Player      object
# Pos         object
# Age          int64
# Tm          object
# G            int64
# GS           int64
# MP         float64
# FG         float64
# FGA        float64
# FG%        float64
# 3P         float64
# 3PA        float64
# 3P%        float64
# 2P         float64
# 2PA        float64
# 2P%        float64
# eFG%       float64
# FT         float64
# FTA        float64
# FT%        float64
# ORB        float64
# DRB        float64
# TRB        float64
# AST        float64
# STL        float64
# BLK        float64
# TOV        float64
# PF         float64
# PTS        float64
# Year         int64
# Pts Won    float64
# Pts Max    float64
# Share      float64
# Team        object
# W          float64
# L          float64
# W/L%       float64
# GB         float64
# PS/G       float64
# PA/G       float64
# SRS        float64
# dtype: object

# %% [markdown]
# ### Combing all the datasets together

# %%
stats.to_csv("player_mvp_stats.csv")

# %% [markdown]
# ### Exploring the NBA Data

# %% [markdown]
# We have our final dataset created and can now do statistical analysis

# %%
highest_scorers = stats[stats["G"] > 70].sort_values("PTS", ascending=False)

# %%
highest_scorers.head(20)
# Out:
#                   Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  ...  \
# 9634        James Harden  PG   29  HOU  78  78  36.8  10.8  24.5  0.442  ...
# 1051         Kobe Bryant  SG   27  LAL  80  80  41.0  12.2  27.2  0.450  ...
# 4425       Allen Iverson  PG   30  PHI  72  72  43.1  11.3  25.3  0.447  ...
# 9953      Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495  ...
# 6871       Tracy McGrady  SG   23  ORL  75  74  39.4  11.1  24.2  0.457  ...
# 6300        Kevin Durant  SF   25  OKC  81  81  38.5  10.5  20.8  0.503  ...
# 6352   Russell Westbrook  PG   28  OKC  81  81  34.6  10.2  24.0  0.425  ...
# 1065         Kobe Bryant  SG   28  LAL  77  77  40.8  10.6  22.8  0.463  ...
# 9927      Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539  ...
# 3263        LeBron James  SF   21  CLE  79  79  42.5  11.1  23.1  0.480  ...
# 968        Allen Iverson  SG   25  PHI  71  71  42.0  10.7  25.5  0.420  ...
# ...

# %%
highest_scorers.head(10).plot.bar("Player", "PTS")
# Out:
# <Axes: xlabel='Player'>

# %%
# highest for each year
highest_scoring_year = stats.groupby("Year").apply(lambda x: x.sort_values("PTS", ascending=False).head(1))
highest_scoring_year
# Out:
#                        Player Pos  Age   Tm   G  GS    MP    FG   FGA    FG%  \
# Year
# 1991 9927      Michael Jordan  SG   27  CHI  82  82  37.0  12.1  22.4  0.539
# 1992 9940      Michael Jordan  SG   28  CHI  80  80  38.8  11.8  22.7  0.519
# 1993 9953      Michael Jordan  SG   29  CHI  78  78  39.3  12.7  25.7  0.495
# 1994 8684      David Robinson   C   28  SAS  80  80  40.5  10.5  20.7  0.507
# 1995 7348    Shaquille O'Neal   C   22  ORL  79  79  37.0  11.8  20.2  0.583
# 1996 10510     Michael Jordan  SG   32  CHI  82  82  37.7  11.2  22.6  0.495
# 1997 10524     Michael Jordan  SG   33  CHI  82  82  37.9  11.2  23.1  0.486
# 1998 10538     Michael Jordan  SG   34  CHI  82  82  38.8  10.7  23.1  0.465
# 1999 937        Allen Iverson  SG   23  PHI  48  48  41.5   9.1  22.0  0.412
# 2000 143     Shaquille O'Neal   C   27  LAL  79  79  40.0  12.1  21.1  0.574
# 2001 968        Allen Iverson  SG   25  PHI  71  71  42.0  10.7  25.5  0.420
# ...

# %%
highest_scoring_year.plot.bar("Year", "PTS")
# Out:
# <Axes: xlabel='Year'>

# %% [markdown]
# It is very important to look at correlations

# %%
correlation = stats.select_dtypes(include=['number']).corr()["Share"]

# %%
correlation
# Out:
# Age        0.018591
# G          0.089332
# GS         0.166074
# MP         0.160770
# FG         0.271383
# FGA        0.245544
# FG%        0.063639
# 3P         0.090897
# 3PA        0.091644
# 3P%        0.011615
# 2P         0.272237
# 2PA        0.249670
# 2P%        0.060475
# eFG%       0.056634
# FT         0.311317
# FTA        0.317467
# FT%        0.035657
# ORB        0.099668
# DRB        0.208146
# TRB        0.181980
# AST        0.195809
# STL        0.174241
# BLK        0.154870
# TOV        0.229116
# PF         0.069961
# PTS        0.282799
# Year      -0.013378
# Pts Won    0.995301
# Pts Max    0.521664
# Share      1.000000
# W          0.123748
# L         -0.123233
# W/L%       0.127763
# GB        -0.102557
# PS/G       0.048713
# PA/G      -0.041029
# SRS        0.124389
# Name: Share, dtype: float64

# %%
correlation.plot.bar()
# Out:
# <Axes: >
